# %%
# %config IPCompleter.use_jedi=False

# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import phate as ph
import pandas as pd
import scprep as scp

# %% [markdown]
# ### Importing the data

# %% [markdown]
# We import the lOFC BOLD data for the young subjects

# %%
data = pd.read_excel(r"YOUNG\lOFC.xlsx", header=None, engine='openpyxl', sheet_name=i+1)

# %% [markdown]
# Below we see the Voxel-Wise lOFC data for the $1^{st}$ young subject.

# %%
data
# Out:
#            0           1           2           3           4           5     \
# 0    132.100495  109.512556  107.954768  104.839190  105.929642  100.633160
# 1    131.477379  110.603009  108.889441  105.773863  106.708537  101.879391
# 2    131.944716  110.447230  108.577883  105.618084  106.708537  101.567833
# 3    131.944716  110.603009  108.733662  105.773863  106.708537  101.723612
# 4    131.010043  110.914566  109.356778  106.241200  107.331652  102.035170
# ..          ...         ...         ...         ...         ...         ...
# 184  132.567832  109.045220  107.020094  103.904517  105.618084   99.854266
# 185  132.567832  109.356778  107.487431  104.371853  106.085421   99.854266
# 186  131.944716  108.889441  107.020094  104.060296  105.929642   99.698487
# 187  132.879389  110.135672  108.266325  105.462305  107.020094  100.944718
# 188  134.437178  111.226124  109.356778  106.241200  107.954768  101.879391
#
#            6           7           8           9     ...        1690  \
# 0     99.542708  104.060296  114.341702  101.723612  ...  157.648232
# 1    100.944718  102.969843  113.562808  101.100497  ...  157.336674
# 2    100.788939  103.904517  114.341702  101.723612  ...  157.336674
# 3    100.788939  104.683411  114.964817  102.346728  ...  157.648232
# 4    101.100497  103.281401  113.874365  101.100497  ...  158.271348
# ..          ...         ...         ...         ...  ...         ...
# 184   99.231150  102.035170  110.758788   99.075371  ...  157.648232
# 185   99.231150  101.879391  111.070345   99.231150  ...  158.271348
# 186   99.231150  101.879391  110.291451   98.452256  ...  159.206021
# 187  100.321602  102.502507  112.316576  100.010044  ...  159.517579
# 188  101.256276  103.281401  112.316576  100.321602  ...  159.206021
#
#            1691        1692        1693        1694        1695        1696  \
# 0    152.974866  175.407025  169.798985  170.110543  170.422101  165.748734
# 1    152.974866  175.407025  169.487427  169.798985  170.422101  165.748734
# 2    152.663308  174.160794  168.864312  168.864312  169.487427  165.125619
# 3    152.974866  175.407025  169.487427  170.422101  170.422101  165.748734
# 4    153.597981  176.964814  171.045216  171.668332  171.668332  166.994965
# ..          ...         ...         ...         ...         ...         ...
# 184  153.597981  176.341698  170.110543  171.045216  171.045216  166.060292
# 185  153.597981  176.653256  170.733658  171.356774  171.356774  166.683407
# 186  154.221097  176.653256  170.422101  171.045216  171.356774  166.683407
# 187  154.844212  177.276372  171.045216  172.291447  172.291447  167.306523
# 188  155.155770  178.522603  171.979890  173.226121  173.226121  167.618081
#
#            1697        1698        1699
# 0    158.894463  166.060292  162.633156
# 1    158.894463  165.748734  162.633156
# 2    158.582905  165.125619  162.010041
# 3    158.894463  165.437176  162.321599
# 4    159.829137  167.618081  164.190945
# ..          ...         ...         ...
# 184  158.894463  166.683407  162.944714
# 185  159.517579  166.994965  163.567830
# 186  159.829137  166.683407  163.256272
# 187  160.452252  167.306523  163.879388
# 188  160.452252  167.929639  164.502503
#
# [189 rows x 1700 columns]

# %%
# We now instantiate the PHATE operator(matrix)/object of the PHATE class
phate_op = ph.PHATE()

# %%
phate_embd =  phate_op.fit_transform(data)
# Out:
# Calculating PHATE...
#   Running PHATE on 189 observations and 1700 variables.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 2.22 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 0.25 seconds.
#     Calculating affinities...
#     Calculated affinities in 1.93 seconds.
#   Calculated graph and diffusion operator in 4.53 seconds.
#   Calculating optimal t...
#     Automatically selected t = 24
#   Calculated optimal t in 0.39 seconds.
#   Calculating diffusion potential...
#   Calculating metric MDS...
#   Calculated metric MDS in 0.43 seconds.
# Calculated PHATE in 6.00 seconds.

# %%
scp.plot.scatter2d(phate_embd, ticks=None, label_prefix='PHATE')
# Out:
# <AxesSubplot:xlabel='PHATE1', ylabel='PHATE2'>
